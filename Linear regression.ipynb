# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
home_prices = pd.read_csv("homeprices.csv")
print (home_prices)
Area = df.Area
price = df.Price
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
from pathlib import Path
Path("myfolder").mkdir(parents=True,exist_ok=True)

# %%
plt.xlabel ("Area(sqr ft)")
plt.ylabel ("price(us$)")
plt.scatter (Area,price, color = 'red', marker= '+' )
# This is for the distrubution of the data

# %%
reg = LinearRegression()
reg.fit(df[['Area']], price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# c:\Users\OGUNDOLIRE BAYOWA\Documents\CONDA\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Note that reg.coef_ means the slope in the Y = MX + b
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Note that reg.intercept means intercept in the Y = MX + b
# Out:
# np.float64(180616.43835616432)

# %% [markdown]
# This is all for the Linear regression
